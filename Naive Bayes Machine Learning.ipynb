# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder 
from sklearn.naive_bayes import CategoricalNB
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %% [markdown]
# ### Load Dataset

# %%
df=pd.read_csv("playing_tennis.csv")

# %%
### Encode Categorical Columns

# %%
le_outlook=LabelEncoder()
le_temp=LabelEncoder()
le_humidity =LabelEncoder()
le_wind=LabelEncoder()
le_play=LabelEncoder()

df["Outlook"]=le_outlook.fit_transform(df["Outlook"])
df["Temperature"]=le_temp.fit_transform(df["Temperature"])
df["Humidity"]=le_humidity.fit_transform(df["Humidity"])
df["Wind"]=le_wind.fit_transform(df["Wind"])
df["Play"]=le_play.fit_transform(df["Play"])

# %%
df.drop("Day",axis=1,inplace=True)

# %%
df
# Out:
#     Outlook  Temperature  Humidity  Wind  Play
# 0         2            1         0     1     0
# 1         2            1         0     0     0
# 2         0            1         0     1     1
# 3         1            2         0     1     1
# 4         1            0         1     1     1
# 5         1            0         1     0     0
# 6         0            0         1     0     1
# 7         2            2         0     1     0
# 8         2            0         1     1     1
# 9         1            2         1     1     1
# 10        2            2         1     0     1
# 11        0            2         0     0     1
# 12        0            1         1     1     1
# 13        1            2         0     0     0

# %% [markdown]
# ### Separate Features and Target

# %%
X=df[["Outlook","Temperature","Humidity","Wind"]]
y=df["Play"]

# %%
### Train Model

# %%
model=CategoricalNB()
model.fit(X,y)
# Out:
# CategoricalNB()

# %%
### Training Predictions

# %%
y_pred=model.predict(X)

# %%
### Evaluation Matrix

# %%
print("Accuracy:",accuracy_score(y,y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y, y_pred))

print("\nClassification Report:")
print(classification_report(y , y_pred , target_names=le_play.classes_))
print("-" * 50)
# Out:
# Accuracy: 0.9285714285714286
#
# Confusion Matrix:
# [[4 1]
#  [0 9]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           No       1.00      0.80      0.89         5
#          Yes       0.90      1.00      0.95         9
#
#     accuracy                           0.93        14
#    macro avg       0.95      0.90      0.92        14
# weighted avg       0.94      0.93      0.93        14
#
# --------------------------------------------------

# %%
### User Input Predictions

# %%
print("Enter values for prediction:")
outlook = input("Outlook (Sunny/Overcast/Rain): ").strip().capitalize()
temperature = input("Temperature (Hot/Mild/Cool): ").strip().capitalize()
humidity = input("Humidity (High/Normal): ").strip().capitalize()
wind = input("Wind (Weak/Strong): ").strip().capitalize()


user_input=[[
    le_outlook.transform([outlook])[0],
    le_temp.transform([temperature])[0],
    le_humidity.transform([humidity])[0],
    le_wind.transform([wind])[0]
]]
prediction=model.predict(user_input)
probabilities=model.predict_proba(user_input)

final_prediction=le_play.inverse_transform(prediction) 
print("\nPredction:",final_prediction[0])
print("Probability for Yes:", probabilities[0][le_play.transform(["Yes"])[0]])
print("Probability for No:",probabilities[0][le_play.transform(["No"])[0]])
# Out:
# Enter values for prediction:
# Outlook (Sunny/Overcast/Rain):  sunny
# Temperature (Hot/Mild/Cool):  Mild
# Humidity (High/Normal):  High
# Wind (Weak/Strong):  Strong
# Predction: No
# Probability for Yes: 0.24469413233458157
# Probability for No: 0.7553058676654182
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but CategoricalNB was fitted with feature names
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but CategoricalNB was fitted with feature names
#   warnings.warn(
